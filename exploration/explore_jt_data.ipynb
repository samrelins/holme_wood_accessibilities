# %%
import sys
sys.path.append('/Users/samrelins/Documents/LIDA/transport_proj/src')

from journey_time_helpers import *

# %%
holme_wood_lsoas = ["E01010612", "E01010819", "E01010820", "E01010821",
                    "E01010822"]
build_accessibility_table(holme_wood_lsoas)
# Out:
# <ipython-input-2-6a8c015cf2a4>:3: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table(holme_wood_lsoas)
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           8.001680
#                           Cycle                             7.946343
#                           Car                               6.923579
# Employment Sites - Medium Public Transport / Walk           8.154908
#                           Cycle                             7.762970
#                           Car                               6.812626
# Employment Sites - Large  Public Transport / Walk          29.275816
#                           Cycle                            21.936467
# ...

# %%
adjacent_lsoas = ["E01010612", "E01010614", "E01010814", "E01010815",
                  "E01010816"]
build_accessibility_table(adjacent_lsoas)
# Out:
# <ipython-input-4-7d2729faaefb>:3: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table(adjacent_lsoas)
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          12.651120
#                           Cycle                             9.982956
#                           Car                               8.502910
# Employment Sites - Medium Public Transport / Walk           8.876123
#                           Cycle                             8.099438
#                           Car                               7.138870
# Employment Sites - Large  Public Transport / Walk          28.027320
#                           Cycle                            21.987679
# ...

# %%
build_accessibility_table(holme_wood_lsoas) - build_accessibility_table(adjacent_lsoas)
# Out:
# <ipython-input-5-769ebc538d3d>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table(holme_wood_lsoas) - build_accessibility_table(adjacent_lsoas)
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          -4.649440
#                           Cycle                            -2.036613
#                           Car                              -1.579331
# Employment Sites - Medium Public Transport / Walk          -0.721215
#                           Cycle                            -0.336468
#                           Car                              -0.326244
# Employment Sites - Large  Public Transport / Walk           1.248496
#                           Cycle                            -0.051213
# ...
