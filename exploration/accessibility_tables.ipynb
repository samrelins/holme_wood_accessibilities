# %%
import sys
sys.path.append('/Users/samrelins/Documents/LIDA/transport_proj/src')

from journey_time_helpers import *

# %% [markdown]
# ## Holme Wood Accessibility
#
# Based on the desired measures of accessibility, I've designed a function to extract and tabulate the relevant information from the DfT transport datasets. As we don't currently have an agreed upon method to aggregate the data, I'll report statistics for each of the 5 Holme Wood LSOAs in separate tables. This may not be the easiest / most informative way to report the data, but it should be simple to adjust the function to aggregate the data once we have agreed an appropriate aggregation method.
#
# ### Bradford 052A - E01010612:

# %%
build_accessibility_table("E01010612")
# Out:
# <ipython-input-2-71e8ec44b4a1>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010612")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           3.162949
#                           Cycle                             6.186517
#                           Car                               6.138532
# Employment Sites - Medium Public Transport / Walk          13.198413
#                           Cycle                             9.578624
#                           Car                               7.847353
# Employment Sites - Large  Public Transport / Walk          28.731258
#                           Cycle                            21.181123
# ...

# %% [markdown]
# ### Bradford 052B - E01010819:

# %%
build_accessibility_table("E01010819")
# Out:
# <ipython-input-3-d768428a0a33>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010819")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           3.498683
#                           Cycle                             6.267769
#                           Car                               5.833981
# Employment Sites - Medium Public Transport / Walk           7.277805
#                           Cycle                             7.575899
#                           Car                               6.605634
# Employment Sites - Large  Public Transport / Walk          28.129026
#                           Cycle                            20.036543
# ...

# %% [markdown]
# ### Bradford 052C - E01010820:

# %%
build_accessibility_table("E01010820")
# Out:
# <ipython-input-4-b32fa84ae1f6>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010820")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          11.443495
#                           Cycle                             9.151125
#                           Car                               7.500859
# Employment Sites - Medium Public Transport / Walk           6.903309
#                           Cycle                             7.162870
#                           Car                               6.400140
# Employment Sites - Large  Public Transport / Walk          30.485633
#                           Cycle                            23.244893
# ...

# %% [markdown]
# ### Bradford 052D - E01010821:

# %%
build_accessibility_table("E01010821")
# Out:
# <ipython-input-5-a3acaaf6353c>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010821")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          12.092525
#                           Cycle                             9.395486
#                           Car                               7.841379
# Employment Sites - Medium Public Transport / Walk          10.852737
#                           Cycle                             8.573424
#                           Car                               7.511535
# Employment Sites - Large  Public Transport / Walk          32.007644
#                           Cycle                            23.685486
# ...

# %% [markdown]
# ### Bradford 052E - E01010822:

# %%
build_accessibility_table("E01010822")
# Out:
# <ipython-input-6-2cc1a0fc452a>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010822")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           9.810747
#                           Cycle                             8.730818
#                           Car                               7.303144
# Employment Sites - Medium Public Transport / Walk           2.542276
#                           Cycle                             5.924033
#                           Car                               5.698471
# Employment Sites - Large  Public Transport / Walk          27.025519
#                           Cycle                            21.534289
# ...

# %% [markdown]
# ### Contiguous LSOAs
#
# The following are the LSOAs that are contiguous with the borders of the Holme Wood area as defined above. I've also included Bradford 046B & 046C as, although they aren't directly contiguous, are pretty close to the border of 052A:
#
# ### Leeds 076D - E01011606

# %%
build_accessibility_table("E01010606")
# Out:
# <ipython-input-7-46398892913c>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010606")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           8.877760
#                           Cycle                             8.171286
#                           Car                               7.633640
# Employment Sites - Medium Public Transport / Walk           2.827517
#                           Cycle                             6.055148
#                           Car                               5.917695
# Employment Sites - Large  Public Transport / Walk          17.921474
#                           Cycle                            10.994778
# ...

# %% [markdown]
# ### Bradford 046B - E01010610

# %%
build_accessibility_table("E01010610")
# Out:
# <ipython-input-8-604f00a1fd8b>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010610")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           4.637397
#                           Cycle                             6.966522
#                           Car                               6.755225
# Employment Sites - Medium Public Transport / Walk           9.214094
#                           Cycle                             8.381429
#                           Car                               7.403531
# Employment Sites - Large  Public Transport / Walk          28.570492
#                           Cycle                            19.781292
# ...

# %% [markdown]
# ### Bradford 046C - E01010611

# %%
build_accessibility_table("E01010611")
# Out:
# <ipython-input-9-ffe8bab02c41>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010611")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           7.765589
#                           Cycle                             8.435740
#                           Car                               7.684904
# Employment Sites - Medium Public Transport / Walk           5.215315
#                           Cycle                             6.865205
#                           Car                               6.508027
# Employment Sites - Large  Public Transport / Walk          25.278119
#                           Cycle                            17.829114
# ...

# %% [markdown]
# ### Bradford 046D - E01010614

# %%
build_accessibility_table("E01010614")
# Out:
# <ipython-input-10-330fc59667bc>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010614")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk           9.092698
#                           Cycle                             8.194349
#                           Car                               7.379473
# Employment Sites - Medium Public Transport / Walk           6.145633
#                           Cycle                             7.224150
#                           Car                               6.728834
# Employment Sites - Large  Public Transport / Walk          24.992599
#                           Cycle                            18.304938
# ...

# %% [markdown]
# ### Bradford 057B - E01010815

# %%
build_accessibility_table("E01010815")
# Out:
# <ipython-input-11-215ff7ce60d8>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010815")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          19.837787
#                           Cycle                            13.142646
#                           Car                              10.464922
# Employment Sites - Medium Public Transport / Walk           7.997484
#                           Cycle                             7.576261
#                           Car                               6.940190
# Employment Sites - Large  Public Transport / Walk          25.799500
#                           Cycle                            21.117998
# ...

# %% [markdown]
# ### Bradford 057C - E01010816

# %%
build_accessibility_table("E01010816")
# Out:
# <ipython-input-12-46254f677e4b>:1: DtypeWarning: Columns (288,289,290,291,297) have mixed types.Specify dtype option on import or set low_memory=False.
#   build_accessibility_table("E01010816")
#                                                                       \
#                                                   Journey Time (min)
# Service                   Mode
# Employment Sites - Small  Public Transport / Walk          18.178591
#                           Cycle                            11.433320
#                           Car                               9.549591
# Employment Sites - Medium Public Transport / Walk          11.963910
#                           Cycle                             9.397162
#                           Car                               7.826898
# Employment Sites - Large  Public Transport / Walk          35.086975
#                           Cycle                            26.272040
# ...
